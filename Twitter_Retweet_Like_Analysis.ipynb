# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timedelta
from datetime import timezone 
from pprint import pprint
import time
import re
from matplotlib import pyplot as plt

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(),wait_on_rate_limit=True)

# %%
news_twitter = pd.read_csv("Resource/News_Twitter_Retweet_Like_CNN.csv")
news_twitter = news_twitter.drop(["Unnamed: 0"],axis=1)
news_twitter_retweet = news_twitter.groupby(['News Created Date'])['Retweet Count'].mean()
news_twitter_like = news_twitter.groupby(['News Created Date'])['Like Count'].mean()

news_tweet_count_per_date = news_twitter[['News Text','News Created Date']]
news_tweet_count_per_date = news_tweet_count_per_date.drop_duplicates()
news_tweet_count_per_date = news_tweet_count_per_date.groupby(['News Created Date'])['News Text'].count()

CNN_news_twitter_retweet_like_by_date = pd.DataFrame({
                                    "CNN Retweet Count Average": news_twitter_retweet,
                                    "CNN Tweet Like Count Average": news_twitter_like,
                                    "CNN Tweets Count per date": news_tweet_count_per_date
    
                                    })

CNN_news_twitter_retweet_like_by_date.head()
# Out:
#                    CNN Retweet Count Average  CNN Tweet Like Count Average  \
# News Created Date
# Apr 01                            336.930556                   1096.361111
# Apr 02                            271.882353                    662.988235
# Apr 03                            211.233696                    459.456522
# Apr 04                            219.136364                    563.142857
# Apr 05                            235.897959                    634.821429
#
#                    CNN Tweets Count per date
# News Created Date
# Apr 01                                    68
# Apr 02                                   143
# Apr 03                                   153
# Apr 04                                   141
# Apr 05                                   161

# %%
news_twitter = pd.read_csv("Resource/News_Twitter_Retweet_Like_Fox.csv")
news_twitter = news_twitter.drop(["Unnamed: 0"],axis=1)
news_twitter_retweet = news_twitter.groupby(['News Created Date'])['Retweet Count'].mean()
news_twitter_like = news_twitter.groupby(['News Created Date'])['Like Count'].mean()

news_tweet_count_per_date = news_twitter[['News Text','News Created Date']]
news_tweet_count_per_date = news_tweet_count_per_date.drop_duplicates()
news_tweet_count_per_date = news_tweet_count_per_date.groupby(['News Created Date'])['News Text'].count()

Fox_news_twitter_retweet_like_by_date = pd.DataFrame({
                                    "Fox Retweet Count Average": news_twitter_retweet,
                                    "Fox Tweet Like Count Average": news_twitter_like,
                                    "Fox Tweets Count per date": news_tweet_count_per_date
    
                                    })

Fox_news_twitter_retweet_like_by_date.head()
# Out:
#                    Fox Retweet Count Average  Fox Tweet Like Count Average  \
# News Created Date
# Apr 03                            298.806452                    909.459677
# Apr 04                            211.004082                    650.387755
# Apr 05                            276.176923                    717.496154
# Apr 06                            250.551913                    721.349727
# Apr 07                            317.781726                    981.781726
#
#                    Fox Tweets Count per date
# News Created Date
# Apr 03                                   124
# Apr 04                                   231
# Apr 05                                   244
# Apr 06                                   170
# Apr 07                                   171

# %%
news_twitter = pd.read_csv("Resource/News_Twitter_Retweet_Like_ABC.csv")
news_twitter = news_twitter.drop(["Unnamed: 0"],axis=1)
news_twitter_retweet = news_twitter.groupby(['News Created Date'])['Retweet Count'].mean()
news_twitter_like = news_twitter.groupby(['News Created Date'])['Like Count'].mean()

news_tweet_count_per_date = news_twitter[['News Text','News Created Date']]
news_tweet_count_per_date = news_tweet_count_per_date.drop_duplicates()
news_tweet_count_per_date = news_tweet_count_per_date.groupby(['News Created Date'])['News Text'].count()

ABC_news_twitter_retweet_like_by_date = pd.DataFrame({
                                    "ABC Retweet Count Average": news_twitter_retweet,
                                    "ABC Tweet Like Count Average": news_twitter_like,
                                    "ABC Tweets Count per date": news_tweet_count_per_date
    
                                    })

ABC_news_twitter_retweet_like_by_date.head()
# Out:
#                    ABC Retweet Count Average  ABC Tweet Like Count Average  \
# News Created Date
# Apr 01                            151.720588                    390.852941
# Apr 02                            143.376147                    328.513761
# Apr 03                            139.572368                    271.039474
# Apr 04                            154.829114                    368.240506
# Apr 05                            182.855072                    478.717391
#
#                    ABC Tweets Count per date
# News Created Date
# Apr 01                                    66
# Apr 02                                   101
# Apr 03                                   144
# Apr 04                                   153
# Apr 05                                   127

# %%
news_twitter = pd.read_csv("Resource/News_Twitter_Retweet_Like_CBS.csv")
news_twitter = news_twitter.drop(["Unnamed: 0"],axis=1)
news_twitter_retweet = news_twitter.groupby(['News Created Date'])['Retweet Count'].mean()
news_twitter_like = news_twitter.groupby(['News Created Date'])['Like Count'].mean()

news_tweet_count_per_date = news_twitter[['News Text','News Created Date']]
news_tweet_count_per_date = news_tweet_count_per_date.drop_duplicates()
news_tweet_count_per_date = news_tweet_count_per_date.groupby(['News Created Date'])['News Text'].count()

CBS_news_twitter_retweet_like_by_date = pd.DataFrame({
                                    "CBS Retweet Count Average": news_twitter_retweet,
                                    "CBS Tweet Like Count Average": news_twitter_like,
                                    "CBS Tweets Count per date": news_tweet_count_per_date
    
                                    })

CBS_news_twitter_retweet_like_by_date.head()
# Out:
#                    CBS Retweet Count Average  CBS Tweet Like Count Average  \
# News Created Date
# Apr 01                             62.594059                    125.366337
# Apr 02                             55.648438                    107.304688
# Apr 03                            105.163522                    147.201258
# Apr 04                             74.284768                    125.556291
# Apr 05                             58.641221                    111.816794
#
#                    CBS Tweets Count per date
# News Created Date
# Apr 01                                    99
# Apr 02                                   125
# Apr 03                                   157
# Apr 04                                   146
# Apr 05                                   123

# %%
news_twitter = pd.read_csv("Resource/News_Twitter_Retweet_Like_NBC.csv")
news_twitter = news_twitter.drop(["Unnamed: 0"],axis=1)
news_twitter_retweet = news_twitter.groupby(['News Created Date'])['Retweet Count'].mean()
news_twitter_like = news_twitter.groupby(['News Created Date'])['Like Count'].mean()

news_tweet_count_per_date = news_twitter[['News Text','News Created Date']]
news_tweet_count_per_date = news_tweet_count_per_date.drop_duplicates()
news_tweet_count_per_date = news_tweet_count_per_date.groupby(['News Created Date'])['News Text'].count()

NBC_news_twitter_retweet_like_by_date = pd.DataFrame({
                                    "NBC Retweet Count Average": news_twitter_retweet,
                                    "NBC Tweet Like Count Average": news_twitter_like,
                                    "NBC Tweets Count per date": news_tweet_count_per_date
    
                                    })

NBC_news_twitter_retweet_like_by_date.head()
# Out:
#                    NBC Retweet Count Average  NBC Tweet Like Count Average  \
# News Created Date
# Apr 01                            104.312500                    143.093750
# Apr 02                            102.715596                    144.357798
# Apr 03                            149.815385                    140.507692
# Apr 04                            162.296296                    216.932099
# Apr 05                            182.870370                    255.833333
#
#                    NBC Tweets Count per date
# News Created Date
# Apr 01                                    63
# Apr 02                                   104
# Apr 03                                   126
# Apr 04                                   160
# Apr 05                                   159

# %%
news_twitter = pd.read_csv("Resource/News_Twitter_Retweet_Like_nytimes.csv")
news_twitter = news_twitter.drop(["Unnamed: 0"],axis=1)
news_twitter_retweet = news_twitter.groupby(['News Created Date'])['Retweet Count'].mean()
news_twitter_like = news_twitter.groupby(['News Created Date'])['Like Count'].mean()

news_tweet_count_per_date = news_twitter[['News Text','News Created Date']]
news_tweet_count_per_date = news_tweet_count_per_date.drop_duplicates()
news_tweet_count_per_date = news_tweet_count_per_date.groupby(['News Created Date'])['News Text'].count()

nytimes_news_twitter_retweet_like_by_date = pd.DataFrame({
                                    "nytimes Retweet Count Average": news_twitter_retweet,
                                    "nytimes Tweet Like Count Average": news_twitter_like,
                                    "nytimes Tweets Count per date": news_tweet_count_per_date
    
                                    })

nytimes_news_twitter_retweet_like_by_date.head()
# Out:
#                    nytimes Retweet Count Average  \
# News Created Date
# Apr 01                                204.457627
# Apr 02                                156.488000
# Apr 03                                155.215827
# Apr 04                                200.267176
# Apr 05                                339.798450
#
#                    nytimes Tweet Like Count Average  \
# News Created Date
# Apr 01                                   498.322034
# Apr 02                                   279.800000
# Apr 03                                   281.050360
# Apr 04                                   336.916031
# Apr 05                                   349.170543
#
#                    nytimes Tweets Count per date
# News Created Date
# Apr 01                                       118
# Apr 02                                       124
# Apr 03                                       136
# Apr 04                                       126
# ...

# %%
news_youtube = pd.read_csv("Resource/CNN_data.csv")
news_youtube = news_youtube.drop(["Unnamed: 0"],axis=1)
new_news_youtube = news_youtube[['Video Title','Video Date','Comment Count','Likes Count']]
new_news_youtube = new_news_youtube.drop_duplicates()
news_youtube_like = new_news_youtube.groupby(['Video Date'])['Likes Count'].mean()

news_youtube_count_per_date = news_youtube[['Video Title','Video Date']]
news_youtube_count_per_date = news_youtube_count_per_date.drop_duplicates()
news_youtube_count_per_date = news_youtube_count_per_date.groupby(['Video Date'])['Video Title'].count()
CNN_news_youtube_like_by_date = pd.DataFrame({
                        
                                    "CNN Youtube Like Count Average": news_youtube_like,
                                    "CNN Youtube Video per date": news_youtube_count_per_date
   
                                    })
CNN_news_youtube_like_by_date.head()
# Out:
#             CNN Youtube Like Count Average  CNN Youtube Video per date
# Video Date
# 2010-03-01                             5.0                           1
# 2010-05-19                           788.0                           1
# 2010-05-20                           137.0                           1
# 2010-08-27                           551.0                           1
# 2010-11-22                             4.0                           1

# %%
news_youtube = pd.read_csv("Resource/Fox_News_data.csv")
news_youtube = news_youtube.drop(["Unnamed: 0"],axis=1)
new_news_youtube = news_youtube[['Video Title','Video Date','Comment Count','Likes Count']]
new_news_youtube = new_news_youtube.drop_duplicates()
news_youtube_like = new_news_youtube.groupby(['Video Date'])['Likes Count'].mean()

news_youtube_count_per_date = news_youtube[['Video Title','Video Date']]
news_youtube_count_per_date = news_youtube_count_per_date.drop_duplicates()
news_youtube_count_per_date = news_youtube_count_per_date.groupby(['Video Date'])['Video Title'].count()
Fox_news_youtube_like_by_date = pd.DataFrame({
                        
                                    "Fox Youtube Like Count Average": news_youtube_like,
                                    "Fox Youtube Video per date": news_youtube_count_per_date
   
                                    })
Fox_news_youtube_like_by_date.head()
# Out:
#             Fox Youtube Like Count Average  Fox Youtube Video per date
# Video Date
# 2015-08-01                            24.0                           1
# 2015-08-11                            13.0                           1
# 2015-08-22                            44.0                           1
# 2015-08-25                          3914.0                           1
# 2015-08-31                            13.0                           1

# %%
news_youtube = pd.read_csv("Resource/ABC_NEWS_DATA.csv")
news_youtube = news_youtube.drop(["Unnamed: 0"],axis=1)
new_news_youtube = news_youtube[['Video Title','Video Date','Comment Count','Likes Count']]
new_news_youtube = new_news_youtube.drop_duplicates()
news_youtube_like = new_news_youtube.groupby(['Video Date'])['Likes Count'].mean()

news_youtube_count_per_date = news_youtube[['Video Title','Video Date']]
news_youtube_count_per_date = news_youtube_count_per_date.drop_duplicates()
news_youtube_count_per_date = news_youtube_count_per_date.groupby(['Video Date'])['Video Title'].count()
ABC_news_youtube_like_by_date = pd.DataFrame({
                        
                                    "ABC Youtube Like Count Average": news_youtube_like,
                                    "ABC Youtube Video per date": news_youtube_count_per_date
   
                                    })
ABC_news_youtube_like_by_date.head()
# Out:
#             ABC Youtube Like Count Average  ABC Youtube Video per date
# Video Date
# 2009-07-10                           280.0                           1
# 2009-08-20                          1771.0                           1
# 2009-08-26                            72.0                           1
# 2009-08-29                           100.0                           1
# 2009-11-05                            72.0                           1

# %%
news_youtube = pd.read_csv("Resource/CBS_NEWS_DATA.csv")
news_youtube = news_youtube.drop(["Unnamed: 0"],axis=1)
new_news_youtube = news_youtube[['Video Title','Video Date','Comment Count','Likes Count']]
new_news_youtube = new_news_youtube.drop_duplicates()
news_youtube_like = new_news_youtube.groupby(['Video Date'])['Likes Count'].mean()

news_youtube_count_per_date = news_youtube[['Video Title','Video Date']]
news_youtube_count_per_date = news_youtube_count_per_date.drop_duplicates()
news_youtube_count_per_date = news_youtube_count_per_date.groupby(['Video Date'])['Video Title'].count()
CBS_news_youtube_like_by_date = pd.DataFrame({
                        
                                    "CBS Youtube Like Count Average": news_youtube_like,
                                    "CBS Youtube Video per date": news_youtube_count_per_date
   
                                    })
CBS_news_youtube_like_by_date.head()
# Out:
#             CBS Youtube Like Count Average  CBS Youtube Video per date
# Video Date
# 2010-10-25                          1814.0                           1
# 2010-11-01                           312.0                           1
# 2010-11-03                             3.0                           1
# 2010-11-14                            10.0                           1
# 2010-12-17                           355.0                           1

# %%
news_youtube = pd.read_csv("Resource/NBCNews_Data.csv")
news_youtube = news_youtube.drop(["Unnamed: 0"],axis=1)
new_news_youtube = news_youtube[['Video Title','Video Date','Comment Count','Likes Count']]
new_news_youtube = new_news_youtube.drop_duplicates()
news_youtube_like = new_news_youtube.groupby(['Video Date'])['Likes Count'].mean()

news_youtube_count_per_date = news_youtube[['Video Title','Video Date']]
news_youtube_count_per_date = news_youtube_count_per_date.drop_duplicates()
news_youtube_count_per_date = news_youtube_count_per_date.groupby(['Video Date'])['Video Title'].count()
NBC_news_youtube_like_by_date = pd.DataFrame({
                        
                                    "NBC Youtube Like Count Average": news_youtube_like,
                                    "NBC Youtube Video per date": news_youtube_count_per_date
   
                                    })
NBC_news_youtube_like_by_date.head()
# Out:
#             NBC Youtube Like Count Average  NBC Youtube Video per date
# Video Date
# 2014-09-04                             7.0                           1
# 2014-09-12                            38.0                           1
# 2014-09-22                            21.0                           1
# 2014-10-02                           100.0                           1
# 2014-12-01                            20.0                           1

# %%
news_youtube = pd.read_csv("Resource/TheNewYorkTimes_data.csv")
news_youtube = news_youtube.drop(["Unnamed: 0"],axis=1)
new_news_youtube = news_youtube[['Video Title','Video Date','Comment Count','Likes Count']]
new_news_youtube = new_news_youtube.drop_duplicates()
news_youtube_like = new_news_youtube.groupby(['Video Date'])['Likes Count'].mean()

news_youtube_count_per_date = news_youtube[['Video Title','Video Date']]
news_youtube_count_per_date = news_youtube_count_per_date.drop_duplicates()
news_youtube_count_per_date = news_youtube_count_per_date.groupby(['Video Date'])['Video Title'].count()
nytimes_news_youtube_like_by_date = pd.DataFrame({
                        
                                    "nytimes Youtube Like Count Average": news_youtube_like,
                                    "nytimes Youtube Video per date": news_youtube_count_per_date
   
                                    })
nytimes_news_youtube_like_by_date.head()
# Out:
#             nytimes Youtube Like Count Average  nytimes Youtube Video per date
# Video Date
# 2006-11-07                             13232.0                               1
# 2006-12-29                              6747.0                               1
# 2007-08-25                               116.0                               1
# 2008-02-04                               228.0                               1
# 2008-02-29                               769.0                               1

# %%
retweet_like = Fox_news_twitter_retweet_like_by_date.merge(CNN_news_twitter_retweet_like_by_date,left_index=True,right_index=True,how='inner')
retweet_like = retweet_like.merge(ABC_news_twitter_retweet_like_by_date,left_index=True,right_index=True,how='inner')
retweet_like = retweet_like.merge(CBS_news_twitter_retweet_like_by_date,left_index=True,right_index=True,how='inner')
retweet_like = retweet_like.merge(NBC_news_twitter_retweet_like_by_date,left_index=True,right_index=True,how='inner')
retweet_like = retweet_like.merge(nytimes_news_twitter_retweet_like_by_date,left_index=True,right_index=True,how='inner')
retweet_like.reset_index(level=0, inplace=True)
retweet_like
# Out:
#    News Created Date  Fox Retweet Count Average  Fox Tweet Like Count Average  \
# 0             Apr 03                 298.806452                    909.459677
# 1             Apr 04                 211.004082                    650.387755
# 2             Apr 05                 276.176923                    717.496154
# 3             Apr 06                 250.551913                    721.349727
# 4             Apr 07                 317.781726                    981.781726
# 5             Apr 08                 318.112840                    957.404669
# 6             Apr 09                 250.148325                    774.712919
# 7             Apr 10                 350.120603                   1015.914573
# 8             Apr 11                 246.868512                    765.148789
# 9             Apr 12                 245.680702                    736.929825
# 10            Apr 13                 353.730000                   1107.535000
# ...

# %%
plt.figure(figsize=(10,7.5))
plt.style.use('seaborn-dark')
x = retweet_like['News Created Date']
y_fox = retweet_like['Fox Tweet Like Count Average']
y_cnn = retweet_like['CNN Tweet Like Count Average']
y_abc = retweet_like['ABC Tweet Like Count Average']
y_cbs = retweet_like['CBS Tweet Like Count Average']
y_nbc = retweet_like['NBC Tweet Like Count Average']
y_nytimes = retweet_like['nytimes Tweet Like Count Average']
plt.plot(x,y_fox,color='lightseagreen', linewidth=2,label='Fox')
plt.plot(x,y_cnn,color='darkorange', linewidth=2,label='CNN')
plt.plot(x,y_abc,color='slateblue', linewidth=2,label='ABC')
plt.plot(x,y_cbs,color='gold', linewidth=2,label='CBS')
plt.plot(x,y_nbc,color='deeppink', linewidth=2,label='NBC')
plt.plot(x,y_nytimes,color='yellowgreen', linewidth=2,label='nytimes')
lgd = plt.legend(title="Average Like Count Per Tweet",loc='lower left', bbox_to_anchor=(1, 0.5))
plt.title("Average Like Count Per Tweet Per Date based on Twitter (04/17/2018)")
plt.ylabel("Average Like Count Per Tweet")
plt.xlabel("Tweet Created Date")
plt.xticks(rotation='vertical')
plt.savefig(f"Result/Twitter_Like_Analysis.png",bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,7.5))
plt.style.use('seaborn-dark')
x = retweet_like['News Created Date']
y_fox = retweet_like['Fox Retweet Count Average']
y_cnn = retweet_like['CNN Retweet Count Average']
y_abc = retweet_like['ABC Retweet Count Average']
y_cbs = retweet_like['CBS Retweet Count Average']
y_nbc = retweet_like['NBC Retweet Count Average']
y_nytimes = retweet_like['nytimes Retweet Count Average']
plt.plot(x,y_fox,color='lightseagreen', linewidth=2,label='Fox')
plt.plot(x,y_cnn,color='darkorange', linewidth=2,label='CNN')
plt.plot(x,y_abc,color='slateblue', linewidth=2,label='ABC')
plt.plot(x,y_cbs,color='gold', linewidth=2,label='CBS')
plt.plot(x,y_nbc,color='deeppink', linewidth=2,label='NBC')
plt.plot(x,y_nytimes,color='yellowgreen', linewidth=2,label='nytimes')
lgd = plt.legend(title="Average Retweet Count Per Tweet",loc='lower left', bbox_to_anchor=(1, 0.5))
plt.title("Average Retweet Count Per Tweet Per Date based on Twitter (04/17/2018)")
plt.ylabel("Average Retweet Count Per Tweet")
plt.xlabel("Tweet Created Date")
plt.xticks(rotation='vertical')
plt.savefig(f"Result/Twitter_Retweet_Analysis.png",bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
youtube_like = Fox_news_youtube_like_by_date.merge(CNN_news_youtube_like_by_date,left_index=True,right_index=True,how='inner')
youtube_like = youtube_like.merge(ABC_news_youtube_like_by_date,left_index=True,right_index=True,how='inner')
youtube_like = youtube_like.merge(CBS_news_youtube_like_by_date,left_index=True,right_index=True,how='inner')
youtube_like = youtube_like.merge(NBC_news_youtube_like_by_date,left_index=True,right_index=True,how='inner')
youtube_like = youtube_like.merge(nytimes_news_youtube_like_by_date,left_index=True,right_index=True,how='inner')
youtube_like.reset_index(level=0, inplace=True)
# youtube_like.loc[youtube_like["nytimes Youtube Like Count Average"]>10000,"nytimes Youtube Like Count Average"]=10000
# youtube_like.loc[youtube_like["CNN Youtube Like Count Average"]>10000,"CNN Youtube Like Count Average"]=10000
# youtube_like.loc[youtube_like["CBS Youtube Like Count Average"]>10000,"CBS Youtube Like Count Average"]=10000
youtube_like
# Out:
#     Video Date  Fox Youtube Like Count Average  Fox Youtube Video per date  \
# 0   2018-02-16                     1511.000000                           2
# 1   2018-03-15                     2180.666667                           3
# 2   2018-03-21                      648.500000                           2
# 3   2018-03-22                     1157.000000                           1
# 4   2018-03-23                      954.500000                           2
# 5   2018-03-26                      165.555556                           9
# 6   2018-03-29                     1015.000000                           7
# 7   2018-03-30                      320.750000                           4
# 8   2018-04-01                     1280.000000                           3
# 9   2018-04-02                      213.533333                          15
# 10  2018-04-03                      423.086957                          23
# ...

# %%
plt.figure(figsize=(10,7.5))
plt.style.use('seaborn-dark')
x = youtube_like['Video Date']
y_fox = youtube_like['Fox Youtube Like Count Average']
y_cnn = youtube_like['CNN Youtube Like Count Average']
y_abc = youtube_like['ABC Youtube Like Count Average']
y_cbs = youtube_like['CBS Youtube Like Count Average']
y_nbc = youtube_like['NBC Youtube Like Count Average']
y_nytimes = youtube_like['nytimes Youtube Like Count Average']
plt.plot(x,y_fox,color='lightseagreen', linewidth=2,label='Fox')
plt.plot(x,y_cnn,color='darkorange', linewidth=2,label='CNN')
plt.plot(x,y_abc,color='slateblue', linewidth=2,label='ABC')
plt.plot(x,y_cbs,color='gold', linewidth=2,label='CBS')
plt.plot(x,y_nbc,color='deeppink', linewidth=2,label='NBC')
plt.plot(x,y_nytimes,color='yellowgreen', linewidth=2,label='nytimes')
lgd = plt.legend(title="Average Like Count Per Video",loc='lower left', bbox_to_anchor=(1, 0.5))
plt.title("Average Like Count Per Video Per Date based on Youtube (04/14/2018)")
plt.ylabel("Average Like Count Per Video")
plt.xlabel("Youtube Video Created Date")
plt.xticks(rotation='vertical')
#plt.text(4, 37000, "New visual investigation:how the Las Vegas gunman planned a massacre", color="black")
plt.savefig(f"Result/Youtube_Like_Analysis.png",bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
youtube_like.set_value(10,"Video Date","Apr 03")
youtube_like.set_value(11,"Video Date","Apr 04")
youtube_like.set_value(12,"Video Date","Apr 05")
youtube_like.set_value(13,"Video Date","Apr 06")
youtube_like.set_value(14,"Video Date","Apr 08")
youtube_like.set_value(15,"Video Date","Apr 09")
youtube_like.set_value(16,"Video Date","Apr 10")
youtube_like.set_value(17,"Video Date","Apr 11")
youtube_like.set_value(18,"Video Date","Apr 12")
youtube_like.set_value(19,"Video Date","Apr 13")
youtube_like.set_value(20,"Video Date","Apr 14")
# youtube_like.drop(youtube_like.index[0:10])
# Out:
# /Users/jiemeizhang/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
# /Users/jiemeizhang/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/jiemeizhang/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
retweet_like = retweet_like.set_index('News Created Date')
retweet_like
# Out:
#                    Fox Retweet Count Average  Fox Tweet Like Count Average  \
# News Created Date
# Apr 03                            298.806452                    909.459677
# Apr 04                            211.004082                    650.387755
# Apr 05                            276.176923                    717.496154
# Apr 06                            250.551913                    721.349727
# Apr 07                            317.781726                    981.781726
# Apr 08                            318.112840                    957.404669
# Apr 09                            250.148325                    774.712919
# Apr 10                            350.120603                   1015.914573
# Apr 11                            246.868512                    765.148789
# Apr 12                            245.680702                    736.929825
# Apr 13                            353.730000                   1107.535000
# ...

# %%
youtube_like = youtube_like.set_index('Video Date')
youtube_like
# Out:
#             Fox Youtube Like Count Average  Fox Youtube Video per date  \
# Video Date
# 2018-02-16                     1511.000000                           2
# 2018-03-15                     2180.666667                           3
# 2018-03-21                      648.500000                           2
# 2018-03-22                     1157.000000                           1
# 2018-03-23                      954.500000                           2
# 2018-03-26                      165.555556                           9
# 2018-03-29                     1015.000000                           7
# 2018-03-30                      320.750000                           4
# 2018-04-01                     1280.000000                           3
# 2018-04-02                      213.533333                          15
# Apr 03                          423.086957                          23
# Apr 04                         3027.333333                           3
# ...

# %%
youtube_tweet_like = retweet_like.merge(youtube_like,left_index=True,right_index=True,how='inner')
youtube_tweet_like.reset_index(inplace=True)
youtube_tweet_like = youtube_tweet_like.rename(columns={"index": "News Created Date"})
youtube_tweet_like
# Out:
#    News Created Date  Fox Retweet Count Average  Fox Tweet Like Count Average  \
# 0             Apr 03                 298.806452                    909.459677
# 1             Apr 04                 211.004082                    650.387755
# 2             Apr 05                 276.176923                    717.496154
# 3             Apr 06                 250.551913                    721.349727
# 4             Apr 08                 318.112840                    957.404669
# 5             Apr 09                 250.148325                    774.712919
# 6             Apr 10                 350.120603                   1015.914573
# 7             Apr 11                 246.868512                    765.148789
# 8             Apr 12                 245.680702                    736.929825
# 9             Apr 13                 353.730000                   1107.535000
# 10            Apr 14                 317.639535                   1032.476744
#
# ...

# %%
plt.figure(figsize=(10,7.5))
plt.style.use('seaborn-dark')
x = youtube_tweet_like['News Created Date']
y_fox_youtube = youtube_tweet_like['Fox Youtube Like Count Average']
y_cnn_youtube = youtube_tweet_like['CNN Youtube Like Count Average']
y_abc_youtube = youtube_tweet_like['ABC Youtube Like Count Average']
y_cbs_youtube = youtube_tweet_like['CBS Youtube Like Count Average']
y_nbc_youtube = youtube_tweet_like['NBC Youtube Like Count Average']
y_nytimes_youtube = youtube_tweet_like['nytimes Youtube Like Count Average']
y_fox_Tweet = youtube_tweet_like['Fox Tweet Like Count Average']
y_cnn_Tweet = youtube_tweet_like['CNN Tweet Like Count Average']
y_abc_Tweet = youtube_tweet_like['ABC Tweet Like Count Average']
y_cbs_Tweet = youtube_tweet_like['CBS Tweet Like Count Average']
y_nbc_Tweet = youtube_tweet_like['NBC Tweet Like Count Average']
y_nytimes_Tweet = youtube_tweet_like['nytimes Tweet Like Count Average']
plt.plot(x,y_fox_youtube,color='lightseagreen', linewidth=2,label='Fox Youtube')
plt.plot(x,y_cnn_youtube,color='darkorange', linewidth=2,label='CNN Youtube')
plt.plot(x,y_abc_youtube,color='slateblue', linewidth=2,label='ABC Youtube')
plt.plot(x,y_cbs_youtube,color='gold', linewidth=2,label='CBS Youtube')
plt.plot(x,y_nbc_youtube,color='deeppink', linewidth=2,label='NBC Youtube')
plt.plot(x,y_nytimes_youtube,color='yellowgreen', linewidth=2,label='nytimes Youtube')
plt.plot(x,y_fox_Tweet,color='lightseagreen',linestyle='dashed', linewidth=2,label='Fox Tweet')
plt.plot(x,y_cnn_Tweet,color='darkorange',linestyle='dashed', linewidth=2,label='CNN Tweet')
plt.plot(x,y_abc_Tweet,color='slateblue', linestyle='dashed',linewidth=2,label='ABC Tweet')
plt.plot(x,y_cbs_Tweet,color='gold',linestyle='dashed', linewidth=2,label='CBS Tweet')
plt.plot(x,y_nbc_Tweet,color='deeppink', linestyle='dashed',linewidth=2,label='NBC Tweet')
plt.plot(x,y_nytimes_Tweet,color='yellowgreen',linestyle='dashed', linewidth=2,label='nytimes Tweet')
lgd = plt.legend(title="Average Like Count Per Tweet/Video",loc='lower left', bbox_to_anchor=(1, 0.5))
plt.title("Average Like Count Per Tweet/Video Per Date (04/3/2018-04/14/2018)")
plt.ylabel("Average Like Count Per Tweet/Video")
plt.xlabel("Tweet/Video Created Date")
plt.xticks(rotation='vertical')
#plt.text(1.5, 4000, "Youtube Shoot", color="black")
plt.savefig(f"Result/Youtube_Tweet_Like_Analysis.png",bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,7.5))
plt.style.use('seaborn-darkgrid')   
plt.scatter(x=youtube_tweet_like['Fox Tweet Like Count Average'], 
            y=youtube_tweet_like['Fox Tweets Count per date'], 
                s=17.7*3, 
                color='lightseagreen', label='Fox',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['CNN Tweet Like Count Average'], 
            y=youtube_tweet_like['CNN Tweets Count per date'], 
                s=40.2*3, 
                color='darkorange', label='CNN',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['ABC Tweet Like Count Average'], 
            y=youtube_tweet_like['ABC Tweets Count per date'], 
                s=13.9*3, 
                color='slateblue', label='ABC',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['CBS Tweet Like Count Average'], 
            y=youtube_tweet_like['CBS Tweets Count per date'], 
                s=6.52*3, 
                color='gold', label='CBS',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['NBC Tweet Like Count Average'], 
            y=youtube_tweet_like['NBC Tweets Count per date'], 
                s=6.03*3, 
                color='deeppink', label='NBC',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['nytimes Tweet Like Count Average'], 
            y=youtube_tweet_like['nytimes Tweets Count per date'], 
                s=41.8*3, 
                color='yellowgreen', label='nytimes',alpha=0.75,edgecolor="black",linewidths=1)

lgd= plt.legend(title="Media",loc='lower left', bbox_to_anchor=(1, 0.5))
lgd.legendHandles[0]._sizes=[90]
lgd.legendHandles[1]._sizes=[90]
lgd.legendHandles[2]._sizes=[90]
lgd.legendHandles[3]._sizes=[90]
lgd.legendHandles[4]._sizes=[90]
lgd.legendHandles[5]._sizes=[90]
plt.title("Tweets News Count vs Like Count (04/3/2018-04/14/2018)")
plt.xlabel("Daily Like Count per tweet")
plt.ylabel("Daily Tweets Count")
plt.text(200, 225, "Circle size correlates with followers count", color="black")
plt.savefig(f"Result/Youtube_Tweet_News_Like_Count_Correlation.png",bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,7.5))
plt.style.use('seaborn-darkgrid')   
plt.scatter(x=youtube_tweet_like['Fox Youtube Like Count Average'], 
            y=youtube_tweet_like['Fox Youtube Video per date'], 
                s=17.7*3, 
                color='lightseagreen', label='Fox',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['CNN Youtube Like Count Average'], 
            y=youtube_tweet_like['CNN Youtube Video per date'], 
                s=40.2*3, 
                color='darkorange', label='CNN',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['ABC Youtube Like Count Average'], 
            y=youtube_tweet_like['ABC Youtube Video per date'], 
                s=13.9*3, 
                color='slateblue', label='ABC',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['CBS Youtube Like Count Average'], 
            y=youtube_tweet_like['CBS Youtube Video per date'], 
                s=6.52*3, 
                color='gold', label='CBS',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['NBC Youtube Like Count Average'], 
            y=youtube_tweet_like['NBC Youtube Video per date'], 
                s=6.03*3, 
                color='deeppink', label='NBC',alpha=0.75,edgecolor="black",linewidths=1)
plt.scatter(x=youtube_tweet_like['nytimes Youtube Like Count Average'], 
            y=youtube_tweet_like['nytimes Youtube Video per date'], 
                s=41.8*3, 
                color='yellowgreen', label='nytimes',alpha=0.75,edgecolor="black",linewidths=1)

lgd= plt.legend(title="Media",loc='lower left', bbox_to_anchor=(1, 0.5))
lgd.legendHandles[0]._sizes=[90]
lgd.legendHandles[1]._sizes=[90]
lgd.legendHandles[2]._sizes=[90]
lgd.legendHandles[3]._sizes=[90]
lgd.legendHandles[4]._sizes=[90]
lgd.legendHandles[5]._sizes=[90]
plt.title("Youtube News Video Count vs Like Count (04/3/2018-04/14/2018)")
plt.xlabel("Daily Like Count per video")
plt.ylabel("Daily Video Count")
plt.xlim(-100,2100)
plt.ylim(0,30)
plt.text(1000, 25, "Circle size correlates with followers count", color="black")
plt.savefig(f"Result/Youtube_News_Like_Count_Correlation.png",bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
